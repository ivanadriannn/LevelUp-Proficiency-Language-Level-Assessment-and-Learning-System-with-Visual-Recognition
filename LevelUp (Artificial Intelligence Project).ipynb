# %% [markdown]
# #**Import library** **bold text**

# %%
import pandas as pd #Python Data Analysis Library
import numpy as np #Python Scientific Library (Umumnya membantu
#dalam urusan list)

#Selective import modul-modul Scikit Learn
#(Scikit Learn memiliki banyak modul machine learning)
from sklearn import linear_model
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %% [markdown]
# #**Mengakses Dataset**

# %% [markdown]
# ##Mengunduh datasate dari link Dicoding Academy

# %%
# !wget --no-check-certificate \
 https://dicodingacademy.blob.core.windows.net/picodiploma/ml_pemula_academy/rockpaperscissors.zip
# Out:
# --2024-01-05 03:07:26--  https://dicodingacademy.blob.core.windows.net/picodiploma/ml_pemula_academy/rockpaperscissors.zip
# Resolving dicodingacademy.blob.core.windows.net (dicodingacademy.blob.core.windows.net)... 20.60.139.65
# Connecting to dicodingacademy.blob.core.windows.net (dicodingacademy.blob.core.windows.net)|20.60.139.65|:443... connected.
# HTTP request sent, awaiting response... 404 The specified resource does not exist.
# 2024-01-05 03:07:27 ERROR 404: The specified resource does not exist..

# %% [markdown]
# ##Mengestrak file Zip

# %%
import os
import zipfile

local_zip = '/content/HSK1d.zip'
zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall('/content/')
zip_ref.close()

# %% [markdown]
# ##Melihat file untuk data gambar

# %%
import os

fold_bei1 = os.path.join('/content/HSK1/bei1')
fold_dong1 = os.path.join('/content/HSK1/dong1')
fold_gou3 = os.path.join('/content/HSK1/gou3')
fold_ji1 = os.path.join('/content/HSK1/ji1')
fold_ling2 = os.path.join('/content/HSK1/ling2')
fold_ma1 = os.path.join('/content/HSK1/ma1')
fold_qing1 = os.path.join('/content/HSK1/qing3')
fold_shu1 = os.path.join('/content/HSK1/shu1')
fold_shui3 = os.path.join('/content/HSK1/shui3')
fold_ting1 = os.path.join('/content/HSK1/ting1')
fold_yu4 = os.path.join('/content/HSK1/yu4')

print('Jumlah total gambar Bei1:', len(os.listdir(fold_bei1)))
print('Jumlah total gambar Dong1:', len(os.listdir(fold_dong1)))
print('Jumlah total gambar Gou3:', len(os.listdir(fold_gou3)))
print('Jumlah total gambar Ji1:', len(os.listdir(fold_ji1)))
print('Jumlah total gambar Ling2:', len(os.listdir(fold_ling2)))
print('Jumlah total gambar Ma1:', len(os.listdir(fold_ma1)))
print('Jumlah total gambar Qing1:', len(os.listdir(fold_qing1)))
print('Jumlah total gambar Shu1:', len(os.listdir(fold_shu1)))
print('Jumlah total gambar Shui3:', len(os.listdir(fold_shui3)))
print('Jumlah total gambar Ting1:', len(os.listdir(fold_ting1)))
print('Jumlah total gambar Yu4:', len(os.listdir(fold_yu4)))

print("Menampilkan nama file gambar:")
file_bei1 = os.listdir(fold_bei1)
print("Bei1:", file_bei1[:5])

file_dong1 = os.listdir(fold_dong1)
print("Dong1:", file_dong1[:5])

file_gou3 = os.listdir(fold_gou3)
print("Gou3:", file_gou3[:5])

file_ji1 = os.listdir(fold_ji1)
print("Ji1:", file_ji1[:5])

file_ling2 = os.listdir(fold_ling2)
print("Ling2:", file_ling2[:5])

file_ma1 = os.listdir(fold_ma1)
print("Ma1:", file_ma1[:5])

file_qing1 = os.listdir(fold_qing1)
print("Qing1:", file_qing1[:5])

file_shu1 = os.listdir(fold_shu1)
print("Shu1:", file_shu1[:5])

file_shui3 = os.listdir(fold_shui3)
print("Shui3:", file_shui3[:5])

file_ting1 = os.listdir(fold_ting1)
print("Ting1:", file_ting1[:5])

file_yu4 = os.listdir(fold_yu4)
print("Yu4:", file_yu4[:5])
# Out:
# Jumlah total gambar Bei1: 51
# Jumlah total gambar Dong1: 51
# Jumlah total gambar Gou3: 50
# Jumlah total gambar Ji1: 50
# Jumlah total gambar Ling2: 50
# Jumlah total gambar Ma1: 50
# Jumlah total gambar Qing1: 51
# Jumlah total gambar Shu1: 40
# Jumlah total gambar Shui3: 50
# Jumlah total gambar Ting1: 50
# Jumlah total gambar Yu4: 50
# Menampilkan nama file gambar:
# Bei1: ['84.png', '85.png', '140.png', '134.png', '74.png']
# Dong1: ['100.png', '140.png', '134.png', '7.png', '74.png']
# Gou3: ['7.png', '114.png', 'Screenshot 2023-12-31 194351.png', '116.png', '122.png']
# Ji1: ['143.png', '107.png', '100.png', '108.png', '7.png']
# Ling2: ['107.png', '84.png', '85.png', '108.png', '74.png']
# Ma1: ['107.png', '84.png', '85.png', '108.png', '7.png']
# Qing1: ['84.png', '85.png', '100.png', '7.png', '74.png']
# Shu1: ['84.png', '85.png', '108.png', '114.png', '116.png']
# Shui3: ['107.png', '100.png', '108.png', '7.png', '114.png']
# ...

# %% [markdown]
# ##Menampilkan gambar

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import matplotlib.image as mpimg

nrows = 11  # Change this to 11
ncols = 4
pic_index = 0

fig = plt.gcf()
fig.set_size_inches(ncols * 4, nrows * 3)

pic_index += 4

gbr_tampil_bei1 = [os.path.join(fold_bei1, fname) for fname in os.listdir(fold_bei1)[:pic_index]]
gbr_tampil_dong1 = [os.path.join(fold_dong1, fname) for fname in os.listdir(fold_dong1)[:pic_index]]
gbr_tampil_gou3 = [os.path.join(fold_gou3, fname) for fname in os.listdir(fold_gou3)[:pic_index]]
gbr_tampil_ji1 = [os.path.join(fold_ji1, fname) for fname in os.listdir(fold_ji1)[:pic_index]]
gbr_tampil_ling2 = [os.path.join(fold_ling2, fname) for fname in os.listdir(fold_ling2)[:pic_index]]
gbr_tampil_ma1 = [os.path.join(fold_ma1, fname) for fname in os.listdir(fold_ma1)[:pic_index]]
gbr_tampil_qing1 = [os.path.join(fold_qing1, fname) for fname in os.listdir(fold_qing1)[:pic_index]]
gbr_tampil_shu1 = [os.path.join(fold_shu1, fname) for fname in os.listdir(fold_shu1)[:pic_index]]
gbr_tampil_shui3 = [os.path.join(fold_shui3, fname) for fname in os.listdir(fold_shui3)[:pic_index]]
gbr_tampil_ting1 = [os.path.join(fold_ting1, fname) for fname in os.listdir(fold_ting1)[:pic_index]]
gbr_tampil_yu4 = [os.path.join(fold_yu4, fname) for fname in os.listdir(fold_yu4)[:pic_index]]

total_subplots = nrows * ncols

for i, img_path in enumerate(gbr_tampil_bei1 + gbr_tampil_dong1 + gbr_tampil_gou3 + gbr_tampil_ji1 + gbr_tampil_ling2
                            + gbr_tampil_ma1 + gbr_tampil_qing1 + gbr_tampil_shu1 + gbr_tampil_shui3
                            + gbr_tampil_ting1 + gbr_tampil_yu4):
    sp = plt.subplot(nrows, ncols, (i % total_subplots) + 1)
    sp.axis('Off')

    img = mpimg.imread(img_path)
    plt.imshow(img)

plt.show()

# %% [markdown]
# #**Mengimport modul **

# %%
pip install --upgrade tensorflow keras_preprocessing
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 475.2/475.2 MB 3.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 5.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.15.0
#     Uninstalling tensorflow-2.15.0:
#       Successfully uninstalled tensorflow-2.15.0
# ...

# %%
import tensorflow as tf                                                           #Mengimpor modul tensorflow
import keras_preprocessing                                                        #Mengimpor modul keras
from keras_preprocessing import image                                             #Mengimpor keras_preprocessing untuk gambar
from keras_preprocessing.image import ImageDataGenerator                          #Mengimpor Image Generator

# %% [markdown]
# ##**Augmentasi & Pemisahan Data menjadi Training dan Validation**

# %%
BASIS_DIR = "/content/HSK1"                                                       #Menyiapkan folder utama
training_datagen = ImageDataGenerator(                                            #Image generator
      rescale = 1./255,                                                           #Menormalisasi data
#>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>AUGMENTASI<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
	    rotation_range=40,                                                          #Menerapkan skenario rotasi gambar hingga 40 derajat
      width_shift_range=0.2,                                                      #Menerapkan skenario pelebaran gambar hingga hingga sebanyak 0.2 dari ukuran asli
      height_shift_range=0.2,                                                     #Menerapkan skenario peninggian gambar hingga hingg sebanyak 0.2 dari ukuran asli
      shear_range=0.2,                                                            #Menerapkan skenario pemangkasan gambar gambar hingga sebanyak 0.2 dari ukuran asli
      zoom_range=0.2,                                                             #Menerapkan skenario zoom gambar hingga sebesar 0.2                                                                      #Menerapkan skenario putar balik gambar secara horizontal
      fill_mode='nearest',

                                                                                  #Mengisi piksel yang kosong dengan nilai piksel terdekat
#>>>>>>>>>>>MEMECAH DATA MENJADI DATA TRAINING DAN DATA VALIDASI<<<<<<<<<<<<<<<<
      validation_split=0.2                                                        #80% Data Training, 20% Data Validasi
      )

# %% [markdown]
# ##Menyiapkan data generator berdasarkan folder

# %%
train_generator = training_datagen.flow_from_directory(                           #Generator data training
	BASIS_DIR,                                                                      #Folder target untuk digenerasi
	target_size=(150,150),                                                          #Mengubah resolusi seluruh gambar menjadi 150x150 piksel
	class_mode='sparse',                                                            #Kelas data kategori untuk klasifikasi multivariabel
  shuffle=True,
  subset='training'
                                                                                  #Untuk data training
  )

validation_generator = training_datagen.flow_from_directory(                      #Generator data validasi
	BASIS_DIR,                                                                      #Folder target untuk digenerasi
	target_size=(150,150),                                                          #Mengubah resolusi seluruh gambar menjadi 150x150 piksel
	class_mode='sparse',                                                            #Kelas data kategori untuk klasifikasi multivariabel
  shuffle=True,
  subset='validation'                                                             #Untuk data validasi
  )
# Out:
# Found 435 images belonging to 11 classes.
# Found 108 images belonging to 11 classes.

# %% [markdown]
# #**Membangun Model neural network**

# %% [markdown]
# ##Model yang digunakan adalah model Sequential

# %%
model = tf.keras.models.Sequential([


    tf.keras.layers.Conv2D(16, (3,3), activation='relu', input_shape=(150, 150, 3)),
    tf.keras.layers.MaxPooling2D(2, 2),

    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),

    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),

    tf.keras.layers.Flatten(),
    tf.keras.layers.Dropout(0.5),

    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(512, activation='relu'),


    tf.keras.layers.Dense(11, activation='softmax')
])

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_3 (Conv2D)           (None, 148, 148, 16)      448
#
#  max_pooling2d_3 (MaxPoolin  (None, 74, 74, 16)        0
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 72, 72, 32)        4640
#
#  max_pooling2d_4 (MaxPoolin  (None, 36, 36, 32)        0
#  g2D)
#
#  conv2d_5 (Conv2D)           (None, 34, 34, 32)        9248
#
#  max_pooling2d_5 (MaxPoolin  (None, 17, 17, 32)        0
#  g2D)
#
#  flatten_1 (Flatten)         (None, 9248)              0
#
#  dropout_1 (Dropout)         (None, 9248)              0
#
#  dense_3 (Dense)             (None, 128)               1183872
#
#  dense_4 (Dense)             (None, 512)               66048
#
#  dense_5 (Dense)             (None, 11)                5643
#
# ...
# Total params: 1269899 (4.84 MB)
# Trainable params: 1269899 (4.84 MB)
# Non-trainable params: 0 (0.00 Byte)
# ...

# %% [markdown]
# #**Melakukan Kompilasi Model**

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# #Melatih Model Jaringan Saraf Tiruan

# %% [markdown]
# #**Ploting Akurasi Training dan Validasi**

# %%
history = model.fit(
    train_generator,
    steps_per_epoch=len(train_generator),
    epochs=100,
    validation_data=validation_generator,
    validation_steps=len(validation_generator),
    verbose=2
)
# Out:
# Epoch 1/100
# 14/14 - 14s - loss: 2.4256 - accuracy: 0.0782 - val_loss: 2.3970 - val_accuracy: 0.0741 - 14s/epoch - 980ms/step
# Epoch 2/100
# 14/14 - 11s - loss: 2.3967 - accuracy: 0.0828 - val_loss: 2.3962 - val_accuracy: 0.0926 - 11s/epoch - 815ms/step
# Epoch 3/100
# 14/14 - 11s - loss: 2.3959 - accuracy: 0.0943 - val_loss: 2.3906 - val_accuracy: 0.0926 - 11s/epoch - 771ms/step
# Epoch 4/100
# 14/14 - 12s - loss: 2.3836 - accuracy: 0.1080 - val_loss: 2.3732 - val_accuracy: 0.0833 - 12s/epoch - 823ms/step
# Epoch 5/100
# 14/14 - 12s - loss: 2.3594 - accuracy: 0.1356 - val_loss: 2.3396 - val_accuracy: 0.0926 - 12s/epoch - 893ms/step
# Epoch 6/100
# 14/14 - 12s - loss: 2.3371 - accuracy: 0.1563 - val_loss: 2.2961 - val_accuracy: 0.1667 - 12s/epoch - 825ms/step
# Epoch 7/100
# 14/14 - 12s - loss: 2.2865 - accuracy: 0.1931 - val_loss: 2.3167 - val_accuracy: 0.1019 - 12s/epoch - 831ms/step
# Epoch 8/100
# ...

# %% [markdown]
# ##Melihat pergerakan besaran nilai akurasi Training dan Validasi

# %%
import matplotlib.pyplot as plt                                                   #Mengimpor modul matplotlib
acc = history.history['accuracy']                                                 #Nilai akurasi training
val_acc = history.history['val_accuracy']                                         #Nilai akurasi validasi
loss = history.history['loss']                                                    #Nilai loss training
val_loss = history.history['val_loss']                                            #Nilai loss validasi

epochs = range(len(acc))                                                          #Jumlah epoch

plt.plot(epochs, acc, 'r', label='Akurasi Training ')                             #Plot nilai akurasi training
plt.plot(epochs, val_acc, 'b', label='Akurasi Validasi')                          #Plot nilai akurasi validasi
plt.title('Akurasi Training dan Validasi')                                        #Menamai gambar
plt.legend(loc=0)                                                                 #Menampilkan legenda
plt.figure()
plt.show()

# %% [markdown]
# #**Uji Coba Model Klasifikasi **

# %% [markdown]
# ##Melakukan simulasi klasifikasi

# %%
import numpy as np
from keras.preprocessing import image
import matplotlib.pyplot as plt
from google.colab import output
from IPython.display import display, Javascript
from base64 import b64decode

# Assuming that 'model' is already defined and loaded with the trained model

character_mapping = {
    0: {'char': 'bei1', 'meaning': 'glass'},
    1: {'char': 'dong1', 'meaning': 'east'},
    2: {'char': 'gou4', 'meaning': 'dog'},
    3: {'char': 'ji1', 'meaning': 'machine'},
    4: {'char': 'ling2', 'meaning': 'zero; fragment; fraction; piece'},
    5: {'char': 'ma1', 'meaning': 'mom'},
    6: {'char': 'qing1', 'meaning': 'please'},
    7: {'char': 'shu1', 'meaning': 'book'},
    8: {'char': 'shui3', 'meaning': 'water'},
    9: {'char': 'ting1', 'meaning': 'hear'},
    10: {'char': 'yu4', 'meaning': 'rain'}
}

# Sort the characters based on their index for sequential testing
sorted_characters = sorted(character_mapping.items(), key=lambda x: x[0])

# Dictionary to keep track of incorrect attempts for each character
incorrect_attempts = {index: 0 for index, _ in sorted_characters}

# Webcam capture function
def take_photo(quality=0.8):
    js = Javascript('''
        async function takePhoto(quality) {
            const div = document.createElement('div');
            const capture = document.createElement('button');
            capture.textContent = 'Capture';
            div.appendChild(capture);

            const video = document.createElement('video');
            video.style.display = 'block';
            const stream = await navigator.mediaDevices.getUserMedia({ 'video': true });

            document.body.appendChild(div);
            div.appendChild(video);
            video.srcObject = stream;
            await video.play();

            // Resize the output to fit the video element.
            google.colab.output.setIframeHeight(document.documentElement.scrollHeight, true);

            // Wait for the Capture button to be clicked.
            await new Promise((resolve) => capture.onclick = resolve);

            const canvas = document.createElement('canvas');
            canvas.width = video.videoWidth;
            canvas.height = video.videoHeight;
            canvas.getContext('2d').drawImage(video, 0, 0);
            stream.getVideoTracks()[0].stop();
            div.remove();
            return canvas.toDataURL('image/jpeg', quality);
        }
    ''')
    display(js)

    # Use the takePhoto function to capture the image
    data = output.eval_js('takePhoto({})'.format(quality))
    binary_data = b64decode(data.split(',')[1])

    # Save the captured image
    with open('captured_image.jpg', 'wb') as f:
        f.write(binary_data)

# Loop through characters
for i, (index, char_info) in enumerate(sorted_characters):
    char = char_info['char']
    meaning = char_info['meaning']

    correct_answer = False  # Flag to control moving to the next question

    while not correct_answer:
        print(f"Write the character for '{meaning}' ({char})")

        # Capture an image using the webcam
        take_photo()

        # Load the captured image
        img = image.load_img('captured_image.jpg', target_size=(150, 150))
        imgplot = plt.imshow(img)
        plt.show()  # Display the image
        x = image.img_to_array(img)
        x = np.expand_dims(x, axis=0)

        images = np.vstack([x])
        classes = model.predict(images, batch_size=10)
        predicted_class = np.argmax(classes[0])

        print(f"\nPredicted Character: {character_mapping[predicted_class]['char']}")
        print("Result: ", end="")

        if predicted_class == index:
            print('Correct!')

            # If not the last character, inform the user about the next character
            if i < len(sorted_characters) - 1:
                next_index, next_char_info = sorted_characters[i + 1]
                next_char = next_char_info['char']
                next_meaning = next_char_info['meaning']
                print(f"Move on to the next character: '{next_meaning}' ({next_char})\n")
                correct_answer = True  # Set the flag to move to the next question
            else:
                print('Congratulations! You have passed the HSK1 writing exercise.\n')
                correct_answer = True  # Set the flag to exit the loop

        else:
            # Increment the incorrect attempts counter for the current character
            incorrect_attempts[index] += 1
            print(f'Incorrect! Try again for {char}. '
                  f'This is attempt #{incorrect_attempts[index]}.\n')
# Out:
# Write the character for 'glass' (bei1)
# 1/1 [==============================] - 0s 43ms/step
#
# Predicted Character: bei1
# Result: Correct!
# Move on to the next character: 'east' (dong1)
#
# Write the character for 'east' (dong1)
# 1/1 [==============================] - 0s 24ms/step
#
# Predicted Character: dong1
# Result: Correct!
# Move on to the next character: 'dog' (gou4)
#
# Write the character for 'dog' (gou4)
# 1/1 [==============================] - 0s 37ms/step
#
# Predicted Character: gou4
# Result: Correct!
# Move on to the next character: 'machine' (ji1)
#
# Write the character for 'machine' (ji1)
# 1/1 [==============================] - 0s 24ms/step
#
# Predicted Character: ji1
# Result: Correct!
# Move on to the next character: 'zero; fragment; fraction; piece' (ling2)
#
# Write the character for 'zero; fragment; fraction; piece' (ling2)
# 1/1 [==============================] - 0s 26ms/step
#
# Predicted Character: ling2
# Result: Correct!
# ...
